# %%
#@title Bibliotecas e Ambiente de Execução
import os
import io
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %%
import os
from functions import *

# %%
# parametros iniciais
smoth_DTG = 95
smoth_TGA = 95
temp_inicial = 30   # temperatura minima (°C)
temp_final = 660   # temperatura maxima (°C)

# %%
# Obtendo a lista de arquivos .txt
data_path = 'data'
files = [os.path.join(data_path, file_) for file_ in os.listdir(data_path) if os.path.isfile(os.path.join(data_path, file_))]
files_txt = [arquivo for arquivo in files if arquivo.lower().endswith('.txt')]
files_txt.sort()
print(f'{len(files_txt)} arquivos .txt encontrados.')
# Out:
# 2 arquivos .txt encontrados.

# %%
# execuçao da funçao

for path_ in files_txt:
  print(path_)
  df = open_file(path_, smoth_DTG=smoth_DTG, smoth_TGA=smoth_TGA, temp_inicial=temp_inicial, temp_final=temp_final)
  if df is not None:
    print(df.head())
  else:
    print(f"Falha ao processar: {path_}")
# Out:
# data\E3_CA.txt
#    tempo (s)  temperatura (C)  DTA (uV)  massa (mg)   massa (%)  DTG (%/°C)  \
# 0      177.0        30.167404 -5.037921    6.969315  100.000000         NaN
# 1      178.0        30.200718 -5.080107    6.968355   99.986225   -0.000960
# 2      179.0        30.241177 -5.113026    6.966979   99.966482   -0.001376
# 3      180.0        30.429985 -5.205938    6.965810   99.949708   -0.001169
# 4      181.0        30.564541 -5.255688    6.964490   99.930768   -0.001320
#
#    DTG_smoth (%/°C)  massa (%)_smoth
# 0         -0.001366        99.528308
# 1         -0.001387        99.518443
# 2         -0.001397        99.508432
# 3         -0.001395        99.498449
# 4         -0.001397        99.488429
# data\E3_Fe.txt
#    tempo (s)  temperatura (C)  massa (mg)  DTA (uV)   massa (%)  DTG (%/°C)  \
# 0      148.0        30.163277    0.096433 -1.775056  100.000000         NaN
# 1      149.0        30.252247    0.096018 -1.791938   99.569649   -0.000415
# 2      150.0        30.370403    0.095595 -1.798626   99.131003   -0.000423
# 3      151.0        30.522373    0.095619 -1.841245   99.155891    0.000024
# 4      152.0        30.749424    0.094993 -1.864396   98.506735   -0.000626
#
#    DTG_smoth (%/°C)  massa (%)_smoth
# 0         -0.000066        96.838911
# 1         -0.000062        96.840251
# 2         -0.000063        96.839650
# 3         -0.000068        96.832973
# 4         -0.000079        96.813810
